# %%
import openpyxl
from openpyxl import Workbook
from openpyxl.styles import Color, PatternFill, Font, Border
from openpyxl.styles import colors
from openpyxl.cell import Cell
import xlrd
from openpyxl import load_workbook
from openpyxl import worksheet
import numpy as np
import pandas as pd
from xlrd import open_workbook
import matplotlib.pyplot as plt

hsif1 = pd.read_excel("data_store1.xlsx");
hsif2 = pd.read_excel("data_store2.xlsx");
x1 = hsif1.icol(0);
y1 = hsif1.icol(1);
x2 = hsif2.icol(0);
y2 = hsif2.icol(1);

plt.plot(x1, y1);
plt.plot(x2, y2);
plt.show();
# Out:
# /home/harsh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:16: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
# /home/harsh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:17: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
# /home/harsh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:18: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
# /home/harsh/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:19: FutureWarning: icol(i) is deprecated. Please use .iloc[:,i]
